# %%
import pandas as pd
import requests
import mlflow
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
input = pd.read_json("input_example.json", orient="table")
input.shape
# Out:
# (531, 4)

# %%
url = 'https://renergies99-api-renergy.hf.space/predict'

pred = requests.post(url, input.iloc[42].to_json())
pred.content
# Out:
# b'{"prediction":47.35491214710038}'

# %%
model_uri = 's3://renergies99-mlflow/4/d81138d3368d4c048bafd9c7fefd70d5/artifacts/model'
test_model = mlflow.sklearn.load_model(model_uri)

test_model.predict(input.iloc[[42]])
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\hardy\anaconda3\envs\Jedi\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([47.35491215])
