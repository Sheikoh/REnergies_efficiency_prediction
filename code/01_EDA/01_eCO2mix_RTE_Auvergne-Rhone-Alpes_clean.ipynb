# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv', index_col=0)
# Out:
# C:\Users\jean-\AppData\Local\Temp\ipykernel_6976\2280533107.py:1: DtypeWarning: Columns (12,13,14,15,18,20,25,26,28,30,32,37,38,40,44,47,51,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv', index_col=0)

# %%
df.head()
# Out:
#                                    Nature        Date    Heures  Consommation  \
# Périmètre
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:00:00        8586.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:30:00        8373.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:00:00        8134.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:30:00        8130.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  02:00:00        8102.0
#
#                       Thermique  Nucléaire  Eolien  Solaire  Hydraulique  \
# Périmètre
# Auvergne-Rhône-Alpes      156.0    10710.0    66.0      0.0       3096.0
# Auvergne-Rhône-Alpes      179.0    10622.0    64.0      0.0       2977.0
# Auvergne-Rhône-Alpes      181.0    10652.0    58.0      0.0       2667.0
# Auvergne-Rhône-Alpes      179.0    10662.0    54.0      0.0       2592.0
# Auvergne-Rhône-Alpes      181.0    10600.0    42.0      0.0       2827.0
#
#                       Pompage  ...  TCO Nucléaire (%) TCH Nucléaire (%)  \
# Périmètre                      ...
# Auvergne-Rhône-Alpes   -166.0  ...             124.74             78.92
# Auvergne-Rhône-Alpes   -163.0  ...             126.86             78.28
# Auvergne-Rhône-Alpes   -163.0  ...             130.96             78.50
# Auvergne-Rhône-Alpes   -163.0  ...             131.14             78.57
# Auvergne-Rhône-Alpes   -165.0  ...             130.83             78.11
#
#                      TCO Eolien (%) TCH Eolien (%) TCO Solaire (%)  \
# Périmètre
# Auvergne-Rhône-Alpes           0.77          11.81             0.0
# Auvergne-Rhône-Alpes           0.76          11.45             0.0
# Auvergne-Rhône-Alpes           0.71          10.38             0.0
# Auvergne-Rhône-Alpes           0.66           9.66             0.0
# Auvergne-Rhône-Alpes           0.52           7.51             0.0
#
#                       TCH Solaire (%) TCO Hydraulique (%) TCH Hydraulique (%)  \
# Périmètre
# Auvergne-Rhône-Alpes              0.0               36.06               26.25
# Auvergne-Rhône-Alpes              0.0               35.55               25.24
# Auvergne-Rhône-Alpes              0.0               32.79               22.61
# Auvergne-Rhône-Alpes              0.0               31.88               21.98
# Auvergne-Rhône-Alpes              0.0               34.89               23.97
#
#                      TCO Bioénergies (%) TCH Bioénergies (%)
# Périmètre
# Auvergne-Rhône-Alpes                1.55               71.12
# Auvergne-Rhône-Alpes                1.45               64.71
# Auvergne-Rhône-Alpes                1.49               64.71
# Auvergne-Rhône-Alpes                1.50               65.24
# Auvergne-Rhône-Alpes                1.48               64.17
#
# [5 rows x 66 columns]

# %%
df.shape
# Out:
# (70132, 66)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70132 entries, Auvergne-Rhône-Alpes to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition, ni en cas de prévisions qui se révèleraient imprécises.
# Data columns (total 66 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Nature                                                               70128 non-null  object
#  1   Date                                                                 70128 non-null  object
#  2   Heures                                                               70128 non-null  object
#  3   Consommation                                                         70128 non-null  float64
#  4   Thermique                                                            70128 non-null  float64
#  5   Nucléaire                                                            70128 non-null  float64
#  6   Eolien                                                               70128 non-null  float64
#  7   Solaire                                                              70128 non-null  float64
#  8   Hydraulique                                                          70128 non-null  float64
#  9   Pompage                                                              70128 non-null  float64
#  10  Bioénergies                                                          70128 non-null  float64
#  11  Stockage batterie                                                    70128 non-null  object
#  12  Déstockage batterie                                                  70128 non-null  object
#  13  Eolien terrestre                                                     70128 non-null  object
#  14  Eolien offshore                                                      70128 non-null  object
#  15  Ech. physiques                                                       70128 non-null  float64
#  16  Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes      70128 non-null  object
#  17  Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes  70080 non-null  object
#  18  Flux physiques de Bretagne vers Auvergne-Rhône-Alpes                 70128 non-null  object
#  19  Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes      70080 non-null  object
#  20  Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes                70128 non-null  object
#  21  Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes          70128 non-null  object
#  22  Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes             70128 non-null  object
#  23  Flux physiques de Normandie vers Auvergne-Rhône-Alpes                70128 non-null  object
#  24  Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes       70080 non-null  object
#  25  Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes                 70080 non-null  object
#  26  Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes         70128 non-null  object
#  27  Flux physiques de PACA vers Auvergne-Rhône-Alpes                     70080 non-null  object
#  28  Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes     70128 non-null  object
#  29  Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté  70128 non-null  object
#  30  Flux physiques de Auvergne-Rhône-Alpes vers Bretagne                 70128 non-null  object
#  31  Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire      70128 non-null  object
#  32  Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est                70128 non-null  object
#  33  Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France          70128 non-null  object
#  34  Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France            70128 non-null  object
#  35  Flux physiques de Auvergne-Rhône-Alpes vers Normandie                70128 non-null  object
#  36  Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine       70128 non-null  object
#  37  Flux physiques de Auvergne-Rhône-Alpes vers Occitanie                70128 non-null  object
#  38  Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire         70128 non-null  object
#  39  Flux physiques de Auvergne-Rhône-Alpes vers PACA                     70128 non-null  object
#  40  Flux physiques Allemagne vers Auvergne-Rhône-Alpes                   70128 non-null  object
#  41  Flux physiques Belgique vers Auvergne-Rhône-Alpes                    70128 non-null  object
#  42  Flux physiques Espagne vers Auvergne-Rhône-Alpes                     70128 non-null  object
#  43  Flux physiques Italie vers Auvergne-Rhône-Alpes                      70080 non-null  object
#  44  Flux physiques Luxembourg vers Auvergne-Rhône-Alpes                  70128 non-null  object
#  45  Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes                 70128 non-null  object
#  46  Flux physiques Suisse vers Auvergne-Rhône-Alpes                      70080 non-null  object
#  47  Flux physiques de Auvergne-Rhône-Alpes vers Allemagne                70128 non-null  object
#  48  Flux physiques de Auvergne-Rhône-Alpes vers Belgique                 70128 non-null  object
#  49  Flux physiques de Auvergne-Rhône-Alpes vers Espagne                  70128 non-null  object
#  50  Flux physiques de Auvergne-Rhône-Alpes vers Italie                   70128 non-null  object
#  51  Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg               70128 non-null  object
#  52  Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni              70128 non-null  object
#  53  Flux physiques de Auvergne-Rhône-Alpes vers Suisse                   70128 non-null  object
#  54  TCO Thermique (%)                                                    70128 non-null  float64
#  55  TCH Thermique (%)                                                    70128 non-null  float64
#  56  TCO Nucléaire (%)                                                    70128 non-null  float64
#  57  TCH Nucléaire (%)                                                    70128 non-null  float64
#  58  TCO Eolien (%)                                                       70128 non-null  float64
#  59  TCH Eolien (%)                                                       70128 non-null  float64
#  60  TCO Solaire (%)                                                      70128 non-null  float64
#  61  TCH Solaire (%)                                                      70128 non-null  float64
#  62  TCO Hydraulique (%)                                                  70128 non-null  float64
#  63  TCH Hydraulique (%)                                                  70128 non-null  float64
#  64  TCO Bioénergies (%)                                                  70128 non-null  float64
#  65  TCH Bioénergies (%)                                                  70128 non-null  float64
# dtypes: float64(21), object(45)
# memory usage: 35.8+ MB

# %%
df.describe(include="all")
# Out:
#                      Nature        Date    Heures  Consommation     Thermique  \
# count                 70128       70128     70128  70128.000000  70128.000000
# unique                    2        1461        48           NaN           NaN
# top     Données définitives  2021-01-01  00:00:00           NaN           NaN
# freq                  52560          48      1461           NaN           NaN
# mean                    NaN         NaN       NaN   7162.704669    214.227783
# std                     NaN         NaN       NaN   1483.458548    217.907448
# min                     NaN         NaN       NaN   1824.000000      0.000000
# 25%                     NaN         NaN       NaN   6020.000000     12.000000
# 50%                     NaN         NaN       NaN   7000.000000    132.000000
# 75%                     NaN         NaN       NaN   8109.000000    392.000000
# max                     NaN         NaN       NaN  13974.000000    724.000000
#
#            Nucléaire        Eolien       Solaire   Hydraulique       Pompage  \
# count   70128.000000  70128.000000  70128.000000  70128.000000  70128.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     9156.795631    164.096053    258.767240   3103.614733   -410.846367
# std      1926.000535    122.826455    396.620513   1262.829678    564.607265
# min      3433.000000      0.000000      0.000000    588.000000  -2580.000000
# 25%      7710.000000     63.000000      0.000000   2163.000000   -734.000000
# 50%      9026.000000    138.000000      3.000000   3012.000000    -22.000000
# 75%     10621.000000    238.000000    428.250000   3876.000000    -13.000000
# max     13568.000000    628.000000   2194.000000   8468.000000     -2.000000
#
#         ...  TCO Nucléaire (%)  TCH Nucléaire (%)  TCO Eolien (%)  \
# count   ...       70128.000000       70128.000000    70128.000000
# unique  ...                NaN                NaN             NaN
# top     ...                NaN                NaN             NaN
# freq    ...                NaN                NaN             NaN
# mean    ...         129.796016          67.478235        2.330754
# std     ...          24.263587          14.193099        1.783016
# min     ...          57.880000          25.300000        0.000000
# 25%     ...         112.810000          56.820000        0.910000
# 50%     ...         126.745000          66.510000        1.920000
# 75%     ...         144.370000          78.270000        3.350000
# max     ...         317.050000          99.990000       12.380000
#
#         TCH Eolien (%)  TCO Solaire (%)  TCH Solaire (%) TCO Hydraulique (%)  \
# count     70128.000000     70128.000000     70128.000000        70128.000000
# unique             NaN              NaN              NaN                 NaN
# top                NaN              NaN              NaN                 NaN
# freq               NaN              NaN              NaN                 NaN
# mean         23.548615         3.699900        14.691673           43.986497
# std          17.651185         5.806897        21.809835           17.336786
# min           0.000000         0.000000         0.000000            8.470000
# 25%           9.080000         0.000000         0.000000           30.970000
# 50%          19.710000         0.040000         0.160000           42.180000
# 75%          34.280000         5.870000        25.210000           55.312500
# max          89.620000        35.730000        98.250000          165.570000
#
#        TCH Hydraulique (%) TCO Bioénergies (%) TCH Bioénergies (%)
# count         70128.000000        70128.000000        70128.000000
# unique                 NaN                 NaN                 NaN
# top                    NaN                 NaN                 NaN
# freq                   NaN                 NaN                 NaN
# mean             27.032282            1.680172           60.292503
# std              10.982307            0.390267            5.598429
# min               5.130000            0.700000           38.310000
# 25%              18.870000            1.390000           56.840000
# 50%              26.260000            1.640000           60.850000
# 75%              33.700000            1.930000           64.210000
# max              73.300000            5.480000           73.820000
#
# [11 rows x 66 columns]

# %% [markdown]
# # Vue générale

# %%
# Nombre de  valeurs manquantes
valeurs_manquantes = df.isna().sum()
valeurs_manquantes
# Out:
# Nature                 4
# Date                   4
# Heures                 4
# Consommation           4
# Thermique              4
#                       ..
# TCH Solaire (%)        4
# TCO Hydraulique (%)    4
# TCH Hydraulique (%)    4
# TCO Bioénergies (%)    4
# TCH Bioénergies (%)    4
# Length: 66, dtype: int64

# %%
# Pourcentage de valeurs manquantes
valeurs_manquantes_pourcent = (df.isna().sum() / df.shape[0]) * 100
valeurs_manquantes_pourcent
# Out:
# Nature                 0.005704
# Date                   0.005704
# Heures                 0.005704
# Consommation           0.005704
# Thermique              0.005704
#                          ...
# TCH Solaire (%)        0.005704
# TCO Hydraulique (%)    0.005704
# TCH Hydraulique (%)    0.005704
# TCO Bioénergies (%)    0.005704
# TCH Bioénergies (%)    0.005704
# Length: 66, dtype: float64

# %%
valeurs_manquantes_graph = valeurs_manquantes[valeurs_manquantes > 0].sort_values(ascending=False)

plt.figure(figsize=(10, 5))
# Prise en charge si valeurs manquetes à 0
if valeurs_manquantes_graph.empty:
    ax = plt.gca()
    ax.text(0.5, 0.5, "Aucune valeur manquante",
            ha="center", va="center", fontsize=12)
    ax.axis("off")
else:
    valeurs_manquantes_graph.plot(kind="bar")
    plt.title("Valeurs manquantes par colonne")
    plt.ylabel("Nombre de valeurs manquantes")
    plt.xticks(rotation=45, ha="right")

plt.show()

# %%
# Vérification valeurs numériques float uniques
numeric_float = df.select_dtypes('float64')

for col in numeric_float.columns:
  print(f"Colonne {col} : ", numeric_float[col].nunique())
# Out:
# Colonne Consommation :  7020
# Colonne Thermique :  725
# Colonne Nucléaire :  8365
# Colonne Eolien :  608
# Colonne Solaire :  1861
# Colonne Hydraulique :  6271
# Colonne Pompage :  2290
# Colonne Bioénergies :  70
# Colonne Ech. physiques :  9761
# Colonne TCO Thermique (%) :  995
# Colonne TCH Thermique (%) :  3656
# Colonne TCO Nucléaire (%) :  11574
# Colonne TCH Nucléaire (%) :  6295
# Colonne TCO Eolien (%) :  996
# Colonne TCH Eolien (%) :  3885
# Colonne TCO Solaire (%) :  2689
# Colonne TCH Solaire (%) :  6384
# Colonne TCO Hydraulique (%) :  8072
# Colonne TCH Hydraulique (%) :  5528
# Colonne TCO Bioénergies (%) :  249
# Colonne TCH Bioénergies (%) :  376

# %%
# Vérification valeurs numériques int uniques
numeric_int = df.select_dtypes('int64')

for col in numeric_int.columns:
  print(f"Colonne {col} : ", numeric_int[col].nunique())

# %%
# Vérification valeurs non numériques float uniques
non_numeric = df.select_dtypes('object')

for col in non_numeric.columns:
  print(f"Colonne {col} : ", non_numeric[col].nunique())
# Out:
# Colonne Nature :  2
# Colonne Date :  1461
# Colonne Heures :  48
# Colonne Stockage batterie :  3
# Colonne Déstockage batterie :  3
# Colonne Eolien terrestre :  3
# Colonne Eolien offshore :  3
# Colonne Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes :  4713
# Colonne Flux physiques de Bretagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes :  2841
# Colonne Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Normandie vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes :  586
# Colonne Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes :  1521
# Colonne Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de PACA vers Auvergne-Rhône-Alpes :  930
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté :  7774
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Bretagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire :  1970
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Normandie :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine :  1021
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Occitanie :  12508
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers PACA :  2644
# Colonne Flux physiques Allemagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Belgique vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Espagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Italie vers Auvergne-Rhône-Alpes :  1415
# Colonne Flux physiques Luxembourg vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Suisse vers Auvergne-Rhône-Alpes :  2350
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Allemagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Belgique :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Espagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Italie :  8432
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Suisse :  5374

# %% [markdown]
# # Cleaning

# %%
df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)
# Out:
# C:\Users\jean-\AppData\Local\Temp\ipykernel_6976\2168416036.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.shape
# Out:
# (70132, 66)

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70132 entries, Auvergne-Rhône-Alpes to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition, ni en cas de prévisions qui se révèleraient imprécises.
# Data columns (total 66 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   nature                                                               70128 non-null  object
#  1   date                                                                 70128 non-null  object
#  2   heures                                                               70128 non-null  object
#  3   consommation                                                         70128 non-null  float64
#  4   thermique                                                            70128 non-null  float64
#  5   nucléaire                                                            70128 non-null  float64
#  6   eolien                                                               70128 non-null  float64
#  7   solaire                                                              70128 non-null  float64
#  8   hydraulique                                                          70128 non-null  float64
#  9   pompage                                                              70128 non-null  float64
#  10  bioénergies                                                          70128 non-null  float64
#  11  stockage_batterie                                                    70127 non-null  object
#  12  déstockage_batterie                                                  70127 non-null  object
#  13  eolien_terrestre                                                     70127 non-null  object
#  14  eolien_offshore                                                      70127 non-null  object
#  15  ech._physiques                                                       70128 non-null  float64
#  16  flux_physiques_d'auvergne-rhône-alpes_vers_auvergne-rhône-alpes      0 non-null      float64
#  17  flux_physiques_de_bourgogne-franche-comté_vers_auvergne-rhône-alpes  17520 non-null  object
#  18  flux_physiques_de_bretagne_vers_auvergne-rhône-alpes                 0 non-null      float64
#  19  flux_physiques_de_centre-val_de_loire_vers_auvergne-rhône-alpes      17520 non-null  object
#  20  flux_physiques_de_grand-est_vers_auvergne-rhône-alpes                0 non-null      float64
#  21  flux_physiques_de_hauts-de-france_vers_auvergne-rhône-alpes          0 non-null      float64
#  22  flux_physiques_d'ile-de-france_vers_auvergne-rhône-alpes             0 non-null      float64
#  23  flux_physiques_de_normandie_vers_auvergne-rhône-alpes                0 non-null      float64
#  24  flux_physiques_de_nouvelle-aquitaine_vers_auvergne-rhône-alpes       17520 non-null  object
#  25  flux_physiques_d'occitanie_vers_auvergne-rhône-alpes                 17520 non-null  object
#  26  flux_physiques_de_pays-de-la-loire_vers_auvergne-rhône-alpes         0 non-null      float64
#  27  flux_physiques_de_paca_vers_auvergne-rhône-alpes                     17520 non-null  object
#  28  flux_physiques_de_auvergne-rhône-alpes_vers_auvergne-rhône-alpes     0 non-null      float64
#  29  flux_physiques_de_auvergne-rhône-alpes_vers_bourgogne-franche-comté  52559 non-null  object
#  30  flux_physiques_de_auvergne-rhône-alpes_vers_bretagne                 0 non-null      float64
#  31  flux_physiques_de_auvergne-rhône-alpes_vers_centre-val_de_loire      52559 non-null  object
#  32  flux_physiques_de_auvergne-rhône-alpes_vers_grand-est                0 non-null      float64
#  33  flux_physiques_de_auvergne-rhône-alpes_vers_hauts-de-france          0 non-null      float64
#  34  flux_physiques_de_auvergne-rhône-alpes_vers_ile-de-france            0 non-null      float64
#  35  flux_physiques_de_auvergne-rhône-alpes_vers_normandie                0 non-null      float64
#  36  flux_physiques_de_auvergne-rhône-alpes_vers_nouvelle-aquitaine       52559 non-null  object
#  37  flux_physiques_de_auvergne-rhône-alpes_vers_occitanie                52559 non-null  object
#  38  flux_physiques_de_auvergne-rhône-alpes_vers_pays-de-la-loire         0 non-null      float64
#  39  flux_physiques_de_auvergne-rhône-alpes_vers_paca                     52559 non-null  object
#  40  flux_physiques_allemagne_vers_auvergne-rhône-alpes                   0 non-null      float64
#  41  flux_physiques_belgique_vers_auvergne-rhône-alpes                    0 non-null      float64
#  42  flux_physiques_espagne_vers_auvergne-rhône-alpes                     0 non-null      float64
#  43  flux_physiques_italie_vers_auvergne-rhône-alpes                      17520 non-null  object
#  44  flux_physiques_luxembourg_vers_auvergne-rhône-alpes                  0 non-null      float64
#  45  flux_physiques_royaume-uni_vers_auvergne-rhône-alpes                 0 non-null      float64
#  46  flux_physiques_suisse_vers_auvergne-rhône-alpes                      17520 non-null  object
#  47  flux_physiques_de_auvergne-rhône-alpes_vers_allemagne                0 non-null      float64
#  48  flux_physiques_de_auvergne-rhône-alpes_vers_belgique                 0 non-null      float64
#  49  flux_physiques_de_auvergne-rhône-alpes_vers_espagne                  0 non-null      float64
#  50  flux_physiques_de_auvergne-rhône-alpes_vers_italie                   52559 non-null  object
#  51  flux_physiques_de_auvergne-rhône-alpes_vers_luxembourg               0 non-null      float64
#  52  flux_physiques_de_auvergne-rhône-alpes_vers_royaume-uni              0 non-null      float64
#  53  flux_physiques_de_auvergne-rhône-alpes_vers_suisse                   52559 non-null  object
#  54  tco_thermique_(%)                                                    70128 non-null  float64
#  55  tch_thermique_(%)                                                    70128 non-null  float64
#  56  tco_nucléaire_(%)                                                    70128 non-null  float64
#  57  tch_nucléaire_(%)                                                    70128 non-null  float64
#  58  tco_eolien_(%)                                                       70128 non-null  float64
#  59  tch_eolien_(%)                                                       70128 non-null  float64
#  60  tco_solaire_(%)                                                      70128 non-null  float64
#  61  tch_solaire_(%)                                                      70128 non-null  float64
#  62  tco_hydraulique_(%)                                                  70128 non-null  float64
#  63  tch_hydraulique_(%)                                                  70128 non-null  float64
#  64  tco_bioénergies_(%)                                                  70128 non-null  float64
#  65  tch_bioénergies_(%)                                                  70128 non-null  float64
# dtypes: float64(45), object(21)
# memory usage: 35.8+ MB
# None
#        consommation     thermique     nucléaire        eolien       solaire  \
# count  70128.000000  70128.000000  70128.000000  70128.000000  70128.000000
# mean    7162.704669    214.227783   9156.795631    164.096053    258.767240
# std     1483.458548    217.907448   1926.000535    122.826455    396.620513
# min     1824.000000      0.000000   3433.000000      0.000000      0.000000
# 25%     6020.000000     12.000000   7710.000000     63.000000      0.000000
# 50%     7000.000000    132.000000   9026.000000    138.000000      3.000000
# 75%     8109.000000    392.000000  10621.000000    238.000000    428.250000
# max    13974.000000    724.000000  13568.000000    628.000000   2194.000000
#
#         hydraulique       pompage   bioénergies  ech._physiques  \
# count  70128.000000  70128.000000  70128.000000    70128.000000
# mean    3103.614733   -410.846367    115.215577    -5439.186644
# std     1262.829678    564.607265     10.380039     2024.309107
# min      588.000000  -2580.000000     74.000000   -12787.000000
# 25%     2163.000000   -734.000000    109.000000    -6897.000000
# 50%     3012.000000    -22.000000    116.000000    -5476.000000
# 75%     3876.000000    -13.000000    122.000000    -4053.000000
# max     8468.000000     -2.000000    143.000000     1270.000000
#
#        flux_physiques_d'auvergne-rhône-alpes_vers_auvergne-rhône-alpes  ...  \
# count                                                0.0                ...
# mean                                                 NaN                ...
# std                                                  NaN                ...
# min                                                  NaN                ...
# 25%                                                  NaN                ...
# 50%                                                  NaN                ...
# 75%                                                  NaN                ...
# max                                                  NaN                ...
#
#        tco_nucléaire_(%)  tch_nucléaire_(%)  tco_eolien_(%)  tch_eolien_(%)  \
# count       70128.000000       70128.000000    70128.000000    70128.000000
# mean          129.796016          67.478235        2.330754       23.548615
# std            24.263587          14.193099        1.783016       17.651185
# min            57.880000          25.300000        0.000000        0.000000
# 25%           112.810000          56.820000        0.910000        9.080000
# 50%           126.745000          66.510000        1.920000       19.710000
# 75%           144.370000          78.270000        3.350000       34.280000
# max           317.050000          99.990000       12.380000       89.620000
#
#        tco_solaire_(%)  tch_solaire_(%)  tco_hydraulique_(%)  \
# count     70128.000000     70128.000000         70128.000000
# mean          3.699900        14.691673            43.986497
# std           5.806897        21.809835            17.336786
# min           0.000000         0.000000             8.470000
# 25%           0.000000         0.000000            30.970000
# 50%           0.040000         0.160000            42.180000
# 75%           5.870000        25.210000            55.312500
# max          35.730000        98.250000           165.570000
#
#        tch_hydraulique_(%)  tco_bioénergies_(%)  tch_bioénergies_(%)
# count         70128.000000         70128.000000         70128.000000
# mean             27.032282             1.680172            60.292503
# std              10.982307             0.390267             5.598429
# min               5.130000             0.700000            38.310000
# 25%              18.870000             1.390000            56.840000
# 50%              26.260000             1.640000            60.850000
# 75%              33.700000             1.930000            64.210000
# max              73.300000             5.480000            73.820000
#
# [8 rows x 45 columns]

# %%
df.head()
# Out:
#                                    nature        date    heures  consommation  \
# Périmètre
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:00:00        8586.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:30:00        8373.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:00:00        8134.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:30:00        8130.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  02:00:00        8102.0
#
#                       thermique  nucléaire  eolien  solaire  hydraulique  \
# Périmètre
# Auvergne-Rhône-Alpes      156.0    10710.0    66.0      0.0       3096.0
# Auvergne-Rhône-Alpes      179.0    10622.0    64.0      0.0       2977.0
# Auvergne-Rhône-Alpes      181.0    10652.0    58.0      0.0       2667.0
# Auvergne-Rhône-Alpes      179.0    10662.0    54.0      0.0       2592.0
# Auvergne-Rhône-Alpes      181.0    10600.0    42.0      0.0       2827.0
#
#                       pompage  ...  tco_nucléaire_(%) tch_nucléaire_(%)  \
# Périmètre                      ...
# Auvergne-Rhône-Alpes   -166.0  ...             124.74             78.92
# Auvergne-Rhône-Alpes   -163.0  ...             126.86             78.28
# Auvergne-Rhône-Alpes   -163.0  ...             130.96             78.50
# Auvergne-Rhône-Alpes   -163.0  ...             131.14             78.57
# Auvergne-Rhône-Alpes   -165.0  ...             130.83             78.11
#
#                      tco_eolien_(%) tch_eolien_(%) tco_solaire_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes           0.77          11.81             0.0
# Auvergne-Rhône-Alpes           0.76          11.45             0.0
# Auvergne-Rhône-Alpes           0.71          10.38             0.0
# Auvergne-Rhône-Alpes           0.66           9.66             0.0
# Auvergne-Rhône-Alpes           0.52           7.51             0.0
#
#                       tch_solaire_(%)  tco_hydraulique_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes              0.0                36.06
# Auvergne-Rhône-Alpes              0.0                35.55
# Auvergne-Rhône-Alpes              0.0                32.79
# Auvergne-Rhône-Alpes              0.0                31.88
# Auvergne-Rhône-Alpes              0.0                34.89
#
#                      tch_hydraulique_(%)  tco_bioénergies_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes               26.25                 1.55
# Auvergne-Rhône-Alpes               25.24                 1.45
# Auvergne-Rhône-Alpes               22.61                 1.49
# Auvergne-Rhône-Alpes               21.98                 1.50
# Auvergne-Rhône-Alpes               23.97                 1.48
#
#                      tch_bioénergies_(%)
# Périmètre
# Auvergne-Rhône-Alpes               71.12
# Auvergne-Rhône-Alpes               64.71
# Auvergne-Rhône-Alpes               64.71
# Auvergne-Rhône-Alpes               65.24
# Auvergne-Rhône-Alpes               64.17
#
# [5 rows x 66 columns]

# %%
df.to_csv("../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes_cleaned.csv", index=False)

# %%
df_sample = df.sample(n=30000, random_state=42)

# %%
df_sample.to_csv(
    "../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes_cleaned_sample.csv",
    index=False
)
