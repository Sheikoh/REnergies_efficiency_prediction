# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv', index_col=0)
# Out:
# C:\Users\jean-\AppData\Local\Temp\ipykernel_12124\2280533107.py:1: DtypeWarning: Columns (12,13,14,15,18,20,25,26,28,30,32,37,38,40,44,47,51,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv', index_col=0)

# %%
df.head()
# Out:
#                                    Nature        Date    Heures  Consommation  \
# Périmètre
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:00:00        8586.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:30:00        8373.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:00:00        8134.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:30:00        8130.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  02:00:00        8102.0
#
#                       Thermique  Nucléaire  Eolien  Solaire  Hydraulique  \
# Périmètre
# Auvergne-Rhône-Alpes      156.0    10710.0    66.0      0.0       3096.0
# Auvergne-Rhône-Alpes      179.0    10622.0    64.0      0.0       2977.0
# Auvergne-Rhône-Alpes      181.0    10652.0    58.0      0.0       2667.0
# Auvergne-Rhône-Alpes      179.0    10662.0    54.0      0.0       2592.0
# Auvergne-Rhône-Alpes      181.0    10600.0    42.0      0.0       2827.0
#
#                       Pompage  ...  TCO Nucléaire (%) TCH Nucléaire (%)  \
# Périmètre                      ...
# Auvergne-Rhône-Alpes   -166.0  ...             124.74             78.92
# Auvergne-Rhône-Alpes   -163.0  ...             126.86             78.28
# Auvergne-Rhône-Alpes   -163.0  ...             130.96             78.50
# Auvergne-Rhône-Alpes   -163.0  ...             131.14             78.57
# Auvergne-Rhône-Alpes   -165.0  ...             130.83             78.11
#
#                      TCO Eolien (%) TCH Eolien (%) TCO Solaire (%)  \
# Périmètre
# Auvergne-Rhône-Alpes           0.77          11.81             0.0
# Auvergne-Rhône-Alpes           0.76          11.45             0.0
# Auvergne-Rhône-Alpes           0.71          10.38             0.0
# Auvergne-Rhône-Alpes           0.66           9.66             0.0
# Auvergne-Rhône-Alpes           0.52           7.51             0.0
#
#                       TCH Solaire (%) TCO Hydraulique (%) TCH Hydraulique (%)  \
# Périmètre
# Auvergne-Rhône-Alpes              0.0               36.06               26.25
# Auvergne-Rhône-Alpes              0.0               35.55               25.24
# Auvergne-Rhône-Alpes              0.0               32.79               22.61
# Auvergne-Rhône-Alpes              0.0               31.88               21.98
# Auvergne-Rhône-Alpes              0.0               34.89               23.97
#
#                      TCO Bioénergies (%) TCH Bioénergies (%)
# Périmètre
# Auvergne-Rhône-Alpes                1.55               71.12
# Auvergne-Rhône-Alpes                1.45               64.71
# Auvergne-Rhône-Alpes                1.49               64.71
# Auvergne-Rhône-Alpes                1.50               65.24
# Auvergne-Rhône-Alpes                1.48               64.17
#
# [5 rows x 66 columns]

# %%
df.shape
# Out:
# (52563, 66)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52563 entries, Auvergne-Rhône-Alpes to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition, ni en cas de prévisions qui se révèleraient imprécises.
# Data columns (total 66 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Nature                                                               52560 non-null  object
#  1   Date                                                                 52560 non-null  object
#  2   Heures                                                               52560 non-null  object
#  3   Consommation                                                         52560 non-null  float64
#  4   Thermique                                                            52560 non-null  float64
#  5   Nucléaire                                                            52560 non-null  float64
#  6   Eolien                                                               52560 non-null  float64
#  7   Solaire                                                              52560 non-null  float64
#  8   Hydraulique                                                          52560 non-null  float64
#  9   Pompage                                                              52560 non-null  float64
#  10  Bioénergies                                                          52560 non-null  float64
#  11  Stockage batterie                                                    52560 non-null  object
#  12  Déstockage batterie                                                  52560 non-null  object
#  13  Eolien terrestre                                                     52560 non-null  object
#  14  Eolien offshore                                                      52560 non-null  object
#  15  Ech. physiques                                                       52560 non-null  float64
#  16  Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes      52560 non-null  object
#  17  Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes  52560 non-null  object
#  18  Flux physiques de Bretagne vers Auvergne-Rhône-Alpes                 52560 non-null  object
#  19  Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes      52560 non-null  object
#  20  Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes                52560 non-null  object
#  21  Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes          52560 non-null  object
#  22  Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes             52560 non-null  object
#  23  Flux physiques de Normandie vers Auvergne-Rhône-Alpes                52560 non-null  object
#  24  Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes       52560 non-null  object
#  25  Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes                 52560 non-null  object
#  26  Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes         52560 non-null  object
#  27  Flux physiques de PACA vers Auvergne-Rhône-Alpes                     52560 non-null  object
#  28  Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes     52560 non-null  object
#  29  Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté  52560 non-null  object
#  30  Flux physiques de Auvergne-Rhône-Alpes vers Bretagne                 52560 non-null  object
#  31  Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire      52560 non-null  object
#  32  Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est                52560 non-null  object
#  33  Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France          52560 non-null  object
#  34  Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France            52560 non-null  object
#  35  Flux physiques de Auvergne-Rhône-Alpes vers Normandie                52560 non-null  object
#  36  Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine       52560 non-null  object
#  37  Flux physiques de Auvergne-Rhône-Alpes vers Occitanie                52560 non-null  object
#  38  Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire         52560 non-null  object
#  39  Flux physiques de Auvergne-Rhône-Alpes vers PACA                     52560 non-null  object
#  40  Flux physiques Allemagne vers Auvergne-Rhône-Alpes                   52560 non-null  object
#  41  Flux physiques Belgique vers Auvergne-Rhône-Alpes                    52560 non-null  object
#  42  Flux physiques Espagne vers Auvergne-Rhône-Alpes                     52560 non-null  object
#  43  Flux physiques Italie vers Auvergne-Rhône-Alpes                      52560 non-null  object
#  44  Flux physiques Luxembourg vers Auvergne-Rhône-Alpes                  52560 non-null  object
#  45  Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes                 52560 non-null  object
#  46  Flux physiques Suisse vers Auvergne-Rhône-Alpes                      52560 non-null  object
#  47  Flux physiques de Auvergne-Rhône-Alpes vers Allemagne                52560 non-null  object
#  48  Flux physiques de Auvergne-Rhône-Alpes vers Belgique                 52560 non-null  object
#  49  Flux physiques de Auvergne-Rhône-Alpes vers Espagne                  52560 non-null  object
#  50  Flux physiques de Auvergne-Rhône-Alpes vers Italie                   52560 non-null  object
#  51  Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg               52560 non-null  object
#  52  Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni              52560 non-null  object
#  53  Flux physiques de Auvergne-Rhône-Alpes vers Suisse                   52560 non-null  object
#  54  TCO Thermique (%)                                                    52560 non-null  float64
#  55  TCH Thermique (%)                                                    52560 non-null  float64
#  56  TCO Nucléaire (%)                                                    52560 non-null  float64
#  57  TCH Nucléaire (%)                                                    52560 non-null  float64
#  58  TCO Eolien (%)                                                       52560 non-null  float64
#  59  TCH Eolien (%)                                                       52560 non-null  float64
#  60  TCO Solaire (%)                                                      52560 non-null  float64
#  61  TCH Solaire (%)                                                      52560 non-null  float64
#  62  TCO Hydraulique (%)                                                  52560 non-null  float64
#  63  TCH Hydraulique (%)                                                  52560 non-null  float64
#  64  TCO Bioénergies (%)                                                  52560 non-null  float64
#  65  TCH Bioénergies (%)                                                  52560 non-null  float64
# dtypes: float64(21), object(45)
# memory usage: 26.9+ MB

# %%
df.describe(include="all")
# Out:
#                      Nature        Date    Heures  Consommation     Thermique  \
# count                 52560       52560     52560  52560.000000  52560.000000
# unique                    1        1095        48           NaN           NaN
# top     Données définitives  2021-01-01  00:00:00           NaN           NaN
# freq                  52560          48      1095           NaN           NaN
# mean                    NaN         NaN       NaN   7190.969597    246.527435
# std                     NaN         NaN       NaN   1530.426393    221.845994
# min                     NaN         NaN       NaN   3616.000000      4.000000
# 25%                     NaN         NaN       NaN   6006.000000     14.000000
# 50%                     NaN         NaN       NaN   7008.000000    198.000000
# 75%                     NaN         NaN       NaN   8170.250000    414.000000
# max                     NaN         NaN       NaN  12751.000000    724.000000
#
#            Nucléaire        Eolien       Solaire   Hydraulique       Pompage  \
# count   52560.000000  52560.000000  52560.000000  52560.000000  52560.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     9167.504091    162.299962    235.225951   2911.284342   -404.372679
# std      1957.762228    119.448308    356.864617   1232.699432    569.642105
# min      3906.000000      0.000000      0.000000    588.000000  -2580.000000
# 25%      7648.750000     64.000000      0.000000   1973.750000   -723.000000
# 50%      9018.000000    137.000000      3.000000   2801.000000    -17.000000
# 75%     10624.000000    236.000000    392.250000   3671.000000    -13.000000
# max     13568.000000    602.000000   1619.000000   8468.000000     -2.000000
#
#         ...  TCO Nucléaire (%)  TCH Nucléaire (%)  TCO Eolien (%)  \
# count   ...       52560.000000       52560.000000    52560.000000
# unique  ...                NaN                NaN             NaN
# top     ...                NaN                NaN             NaN
# freq    ...                NaN                NaN             NaN
# mean    ...         129.481027          67.557150        2.298257
# std     ...          23.930242          14.427161        1.734516
# min     ...          62.560000          28.780000        0.000000
# 25%     ...         112.580000          56.367500        0.920000
# 50%     ...         126.210000          66.460000        1.900000
# 75%     ...         144.250000          78.290000        3.290000
# max     ...         246.860000          99.990000       12.380000
#
#         TCH Eolien (%)  TCO Solaire (%)  TCH Solaire (%) TCO Hydraulique (%)  \
# count     52560.000000     52560.000000     52560.000000        52560.000000
# unique             NaN              NaN              NaN                 NaN
# top                NaN              NaN              NaN                 NaN
# freq               NaN              NaN              NaN                 NaN
# mean         23.767502         3.367090        14.719464           41.011498
# std          17.573202         5.252393        21.784531           16.443089
# min           0.000000         0.000000         0.000000            8.470000
# 25%           9.410000         0.000000         0.000000           28.550000
# 50%          19.890000         0.040000         0.160000           39.050000
# 75%          34.550000         5.330000        25.290000           51.720000
# max          89.620000        26.580000        88.860000          109.160000
#
#        TCH Hydraulique (%) TCO Bioénergies (%) TCH Bioénergies (%)
# count         52560.000000        52560.000000        52560.000000
# unique                 NaN                 NaN                 NaN
# top                    NaN                 NaN                 NaN
# freq                   NaN                 NaN                 NaN
# mean             25.285134            1.670323           59.941966
# std              10.646330            0.394794            5.583063
# min               5.130000            0.750000           38.740000
# 25%              17.190000            1.380000           56.680000
# 50%              24.390000            1.620000           60.530000
# 75%              31.760000            1.920000           63.870000
# max              73.300000            3.430000           73.820000
#
# [11 rows x 66 columns]

# %% [markdown]
# # Vue générale

# %%
# Nombre de  valeurs manquantes
valeurs_manquantes = df.isna().sum()
valeurs_manquantes
# Out:
# Nature                 3
# Date                   3
# Heures                 3
# Consommation           3
# Thermique              3
#                       ..
# TCH Solaire (%)        3
# TCO Hydraulique (%)    3
# TCH Hydraulique (%)    3
# TCO Bioénergies (%)    3
# TCH Bioénergies (%)    3
# Length: 66, dtype: int64

# %%
# Pourcentage de valeurs manquantes
valeurs_manquantes_pourcent = (df.isna().sum() / df.shape[0]) * 100
valeurs_manquantes_pourcent
# Out:
# Nature                 0.005707
# Date                   0.005707
# Heures                 0.005707
# Consommation           0.005707
# Thermique              0.005707
#                          ...
# TCH Solaire (%)        0.005707
# TCO Hydraulique (%)    0.005707
# TCH Hydraulique (%)    0.005707
# TCO Bioénergies (%)    0.005707
# TCH Bioénergies (%)    0.005707
# Length: 66, dtype: float64

# %%
valeurs_manquantes_graph = valeurs_manquantes[valeurs_manquantes > 0].sort_values(ascending=False)

plt.figure(figsize=(10, 5))
# Prise en charge si valeurs manquetes à 0
if valeurs_manquantes_graph.empty:
    ax = plt.gca()
    ax.text(0.5, 0.5, "Aucune valeur manquante",
            ha="center", va="center", fontsize=12)
    ax.axis("off")
else:
    valeurs_manquantes_graph.plot(kind="bar")
    plt.title("Valeurs manquantes par colonne")
    plt.ylabel("Nombre de valeurs manquantes")
    plt.xticks(rotation=45, ha="right")

plt.show()

# %%
# Vérification valeurs numériques float uniques
numeric_float = df.select_dtypes('float64')

for col in numeric_float.columns:
  print(f"Colonne {col} : ", numeric_float[col].nunique())
# Out:
# Colonne Consommation :  6956
# Colonne Thermique :  721
# Colonne Nucléaire :  8039
# Colonne Eolien :  586
# Colonne Solaire :  1551
# Colonne Hydraulique :  5880
# Colonne Pompage :  2279
# Colonne Bioénergies :  70
# Colonne Ech. physiques :  9133
# Colonne TCO Thermique (%) :  990
# Colonne TCH Thermique (%) :  3288
# Colonne TCO Nucléaire (%) :  10751
# Colonne TCH Nucléaire (%) :  6046
# Colonne TCO Eolien (%) :  975
# Colonne TCH Eolien (%) :  3559
# Colonne TCO Solaire (%) :  2335
# Colonne TCH Solaire (%) :  5778
# Colonne TCO Hydraulique (%) :  7379
# Colonne TCH Hydraulique (%) :  5156
# Colonne TCO Bioénergies (%) :  242
# Colonne TCH Bioénergies (%) :  327

# %%
# Vérification valeurs numériques int uniques
numeric_int = df.select_dtypes('int64')

for col in numeric_int.columns:
  print(f"Colonne {col} : ", numeric_int[col].nunique())

# %%
# Vérification valeurs non numériques float uniques
non_numeric = df.select_dtypes('object')

for col in non_numeric.columns:
  print(f"Colonne {col} : ", non_numeric[col].nunique())
# Out:
# Colonne Nature :  1
# Colonne Date :  1095
# Colonne Heures :  48
# Colonne Stockage batterie :  3
# Colonne Déstockage batterie :  3
# Colonne Eolien terrestre :  3
# Colonne Eolien offshore :  3
# Colonne Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes :  4713
# Colonne Flux physiques de Bretagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes :  2841
# Colonne Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Normandie vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes :  586
# Colonne Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes :  1521
# Colonne Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de PACA vers Auvergne-Rhône-Alpes :  930
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté :  6036
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Bretagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire :  1606
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Normandie :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine :  709
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Occitanie :  10168
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers PACA :  2038
# Colonne Flux physiques Allemagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Belgique vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Espagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Italie vers Auvergne-Rhône-Alpes :  1415
# Colonne Flux physiques Luxembourg vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Suisse vers Auvergne-Rhône-Alpes :  2350
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Allemagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Belgique :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Espagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Italie :  6533
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Suisse :  3854

# %% [markdown]
# # Cleaning

# %%
df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)
# Out:
# C:\Users\jean-\AppData\Local\Temp\ipykernel_12124\2168416036.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.shape
# Out:
# (52563, 66)

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52563 entries, Auvergne-Rhône-Alpes to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition, ni en cas de prévisions qui se révèleraient imprécises.
# Data columns (total 66 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   nature                                                               52560 non-null  object
#  1   date                                                                 52560 non-null  object
#  2   heures                                                               52560 non-null  object
#  3   consommation                                                         52560 non-null  float64
#  4   thermique                                                            52560 non-null  float64
#  5   nucléaire                                                            52560 non-null  float64
#  6   eolien                                                               52560 non-null  float64
#  7   solaire                                                              52560 non-null  float64
#  8   hydraulique                                                          52560 non-null  float64
#  9   pompage                                                              52560 non-null  float64
#  10  bioénergies                                                          52560 non-null  float64
#  11  stockage_batterie                                                    52559 non-null  object
#  12  déstockage_batterie                                                  52559 non-null  object
#  13  eolien_terrestre                                                     52559 non-null  object
#  14  eolien_offshore                                                      52559 non-null  object
#  15  ech._physiques                                                       52560 non-null  float64
#  16  flux_physiques_d'auvergne-rhône-alpes_vers_auvergne-rhône-alpes      0 non-null      float64
#  17  flux_physiques_de_bourgogne-franche-comté_vers_auvergne-rhône-alpes  17520 non-null  object
#  18  flux_physiques_de_bretagne_vers_auvergne-rhône-alpes                 0 non-null      float64
#  19  flux_physiques_de_centre-val_de_loire_vers_auvergne-rhône-alpes      17520 non-null  object
#  20  flux_physiques_de_grand-est_vers_auvergne-rhône-alpes                0 non-null      float64
#  21  flux_physiques_de_hauts-de-france_vers_auvergne-rhône-alpes          0 non-null      float64
#  22  flux_physiques_d'ile-de-france_vers_auvergne-rhône-alpes             0 non-null      float64
#  23  flux_physiques_de_normandie_vers_auvergne-rhône-alpes                0 non-null      float64
#  24  flux_physiques_de_nouvelle-aquitaine_vers_auvergne-rhône-alpes       17520 non-null  object
#  25  flux_physiques_d'occitanie_vers_auvergne-rhône-alpes                 17520 non-null  object
#  26  flux_physiques_de_pays-de-la-loire_vers_auvergne-rhône-alpes         0 non-null      float64
#  27  flux_physiques_de_paca_vers_auvergne-rhône-alpes                     17520 non-null  object
#  28  flux_physiques_de_auvergne-rhône-alpes_vers_auvergne-rhône-alpes     0 non-null      float64
#  29  flux_physiques_de_auvergne-rhône-alpes_vers_bourgogne-franche-comté  52559 non-null  object
#  30  flux_physiques_de_auvergne-rhône-alpes_vers_bretagne                 0 non-null      float64
#  31  flux_physiques_de_auvergne-rhône-alpes_vers_centre-val_de_loire      52559 non-null  object
#  32  flux_physiques_de_auvergne-rhône-alpes_vers_grand-est                0 non-null      float64
#  33  flux_physiques_de_auvergne-rhône-alpes_vers_hauts-de-france          0 non-null      float64
#  34  flux_physiques_de_auvergne-rhône-alpes_vers_ile-de-france            0 non-null      float64
#  35  flux_physiques_de_auvergne-rhône-alpes_vers_normandie                0 non-null      float64
#  36  flux_physiques_de_auvergne-rhône-alpes_vers_nouvelle-aquitaine       52559 non-null  object
#  37  flux_physiques_de_auvergne-rhône-alpes_vers_occitanie                52559 non-null  object
#  38  flux_physiques_de_auvergne-rhône-alpes_vers_pays-de-la-loire         0 non-null      float64
#  39  flux_physiques_de_auvergne-rhône-alpes_vers_paca                     52559 non-null  object
#  40  flux_physiques_allemagne_vers_auvergne-rhône-alpes                   0 non-null      float64
#  41  flux_physiques_belgique_vers_auvergne-rhône-alpes                    0 non-null      float64
#  42  flux_physiques_espagne_vers_auvergne-rhône-alpes                     0 non-null      float64
#  43  flux_physiques_italie_vers_auvergne-rhône-alpes                      17520 non-null  object
#  44  flux_physiques_luxembourg_vers_auvergne-rhône-alpes                  0 non-null      float64
#  45  flux_physiques_royaume-uni_vers_auvergne-rhône-alpes                 0 non-null      float64
#  46  flux_physiques_suisse_vers_auvergne-rhône-alpes                      17520 non-null  object
#  47  flux_physiques_de_auvergne-rhône-alpes_vers_allemagne                0 non-null      float64
#  48  flux_physiques_de_auvergne-rhône-alpes_vers_belgique                 0 non-null      float64
#  49  flux_physiques_de_auvergne-rhône-alpes_vers_espagne                  0 non-null      float64
#  50  flux_physiques_de_auvergne-rhône-alpes_vers_italie                   52559 non-null  object
#  51  flux_physiques_de_auvergne-rhône-alpes_vers_luxembourg               0 non-null      float64
#  52  flux_physiques_de_auvergne-rhône-alpes_vers_royaume-uni              0 non-null      float64
#  53  flux_physiques_de_auvergne-rhône-alpes_vers_suisse                   52559 non-null  object
#  54  tco_thermique_(%)                                                    52560 non-null  float64
#  55  tch_thermique_(%)                                                    52560 non-null  float64
#  56  tco_nucléaire_(%)                                                    52560 non-null  float64
#  57  tch_nucléaire_(%)                                                    52560 non-null  float64
#  58  tco_eolien_(%)                                                       52560 non-null  float64
#  59  tch_eolien_(%)                                                       52560 non-null  float64
#  60  tco_solaire_(%)                                                      52560 non-null  float64
#  61  tch_solaire_(%)                                                      52560 non-null  float64
#  62  tco_hydraulique_(%)                                                  52560 non-null  float64
#  63  tch_hydraulique_(%)                                                  52560 non-null  float64
#  64  tco_bioénergies_(%)                                                  52560 non-null  float64
#  65  tch_bioénergies_(%)                                                  52560 non-null  float64
# dtypes: float64(45), object(21)
# memory usage: 26.9+ MB
# None
#        consommation     thermique     nucléaire        eolien       solaire  \
# count  52560.000000  52560.000000  52560.000000  52560.000000  52560.000000
# mean    7190.969597    246.527435   9167.504091    162.299962    235.225951
# std     1530.426393    221.845994   1957.762228    119.448308    356.864617
# min     3616.000000      4.000000   3906.000000      0.000000      0.000000
# 25%     6006.000000     14.000000   7648.750000     64.000000      0.000000
# 50%     7008.000000    198.000000   9018.000000    137.000000      3.000000
# 75%     8170.250000    414.000000  10624.000000    236.000000    392.250000
# max    12751.000000    724.000000  13568.000000    602.000000   1619.000000
#
#         hydraulique       pompage   bioénergies  ech._physiques  \
# count  52560.000000  52560.000000  52560.000000    52560.000000
# mean    2911.284342   -404.372679    114.798877    -5242.317028
# std     1232.699432    569.642105     10.580969     1973.597480
# min      588.000000  -2580.000000     74.000000   -12787.000000
# 25%     1973.750000   -723.000000    108.000000    -6633.000000
# 50%     2801.000000    -17.000000    116.000000    -5268.000000
# 75%     3671.000000    -13.000000    122.000000    -3914.000000
# max     8468.000000     -2.000000    143.000000     1270.000000
#
#        flux_physiques_d'auvergne-rhône-alpes_vers_auvergne-rhône-alpes  ...  \
# count                                                0.0                ...
# mean                                                 NaN                ...
# std                                                  NaN                ...
# min                                                  NaN                ...
# 25%                                                  NaN                ...
# 50%                                                  NaN                ...
# 75%                                                  NaN                ...
# max                                                  NaN                ...
#
#        tco_nucléaire_(%)  tch_nucléaire_(%)  tco_eolien_(%)  tch_eolien_(%)  \
# count       52560.000000       52560.000000    52560.000000    52560.000000
# mean          129.481027          67.557150        2.298257       23.767502
# std            23.930242          14.427161        1.734516       17.573202
# min            62.560000          28.780000        0.000000        0.000000
# 25%           112.580000          56.367500        0.920000        9.410000
# 50%           126.210000          66.460000        1.900000       19.890000
# 75%           144.250000          78.290000        3.290000       34.550000
# max           246.860000          99.990000       12.380000       89.620000
#
#        tco_solaire_(%)  tch_solaire_(%)  tco_hydraulique_(%)  \
# count     52560.000000     52560.000000         52560.000000
# mean          3.367090        14.719464            41.011498
# std           5.252393        21.784531            16.443089
# min           0.000000         0.000000             8.470000
# 25%           0.000000         0.000000            28.550000
# 50%           0.040000         0.160000            39.050000
# 75%           5.330000        25.290000            51.720000
# max          26.580000        88.860000           109.160000
#
#        tch_hydraulique_(%)  tco_bioénergies_(%)  tch_bioénergies_(%)
# count         52560.000000         52560.000000         52560.000000
# mean             25.285134             1.670323            59.941966
# std              10.646330             0.394794             5.583063
# min               5.130000             0.750000            38.740000
# 25%              17.190000             1.380000            56.680000
# 50%              24.390000             1.620000            60.530000
# 75%              31.760000             1.920000            63.870000
# max              73.300000             3.430000            73.820000
#
# [8 rows x 45 columns]

# %%
df.head()
# Out:
#                                    nature        date    heures  consommation  \
# Périmètre
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:00:00        8586.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  00:30:00        8373.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:00:00        8134.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  01:30:00        8130.0
# Auvergne-Rhône-Alpes  Données définitives  2021-01-01  02:00:00        8102.0
#
#                       thermique  nucléaire  eolien  solaire  hydraulique  \
# Périmètre
# Auvergne-Rhône-Alpes      156.0    10710.0    66.0      0.0       3096.0
# Auvergne-Rhône-Alpes      179.0    10622.0    64.0      0.0       2977.0
# Auvergne-Rhône-Alpes      181.0    10652.0    58.0      0.0       2667.0
# Auvergne-Rhône-Alpes      179.0    10662.0    54.0      0.0       2592.0
# Auvergne-Rhône-Alpes      181.0    10600.0    42.0      0.0       2827.0
#
#                       pompage  ...  tco_nucléaire_(%) tch_nucléaire_(%)  \
# Périmètre                      ...
# Auvergne-Rhône-Alpes   -166.0  ...             124.74             78.92
# Auvergne-Rhône-Alpes   -163.0  ...             126.86             78.28
# Auvergne-Rhône-Alpes   -163.0  ...             130.96             78.50
# Auvergne-Rhône-Alpes   -163.0  ...             131.14             78.57
# Auvergne-Rhône-Alpes   -165.0  ...             130.83             78.11
#
#                      tco_eolien_(%) tch_eolien_(%) tco_solaire_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes           0.77          11.81             0.0
# Auvergne-Rhône-Alpes           0.76          11.45             0.0
# Auvergne-Rhône-Alpes           0.71          10.38             0.0
# Auvergne-Rhône-Alpes           0.66           9.66             0.0
# Auvergne-Rhône-Alpes           0.52           7.51             0.0
#
#                       tch_solaire_(%)  tco_hydraulique_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes              0.0                36.06
# Auvergne-Rhône-Alpes              0.0                35.55
# Auvergne-Rhône-Alpes              0.0                32.79
# Auvergne-Rhône-Alpes              0.0                31.88
# Auvergne-Rhône-Alpes              0.0                34.89
#
#                      tch_hydraulique_(%)  tco_bioénergies_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes               26.25                 1.55
# Auvergne-Rhône-Alpes               25.24                 1.45
# Auvergne-Rhône-Alpes               22.61                 1.49
# Auvergne-Rhône-Alpes               21.98                 1.50
# Auvergne-Rhône-Alpes               23.97                 1.48
#
#                      tch_bioénergies_(%)
# Périmètre
# Auvergne-Rhône-Alpes               71.12
# Auvergne-Rhône-Alpes               64.71
# Auvergne-Rhône-Alpes               64.71
# Auvergne-Rhône-Alpes               65.24
# Auvergne-Rhône-Alpes               64.17
#
# [5 rows x 66 columns]

# %%
df.to_csv("../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes_cleaned.csv", index=False)

# %%
df_sample = df.sample(n=30000, random_state=42)

# %%
df_sample.to_csv(
    "../../data/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes_cleaned_sample.csv",
    index=False
)
